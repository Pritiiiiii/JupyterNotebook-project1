# %%
import pandas as pd

# Load the Excel file
file_path = r"D:\data\Tybms.xlsx"  # Replace with your file path
df = pd.read_excel(file_path)

# Display a sample of the data for debugging
print("Original Data Sample:")
print(df.head())

# Ensure Pincode column is treated as integers
if df['PINCODE'].dtype != 'int64':  # Convert to integers if needed
    df['PINCODE'] = pd.to_numeric(df['PINCODE'], errors='coerce', downcast='integer')

# Hardcoded pincodes for testing (replace with user input if needed)
user_input = "421204, 421301, 421202, 421203, 421201, 421306, 421002, 421103"
pincode_list = [int(pincode.strip()) for pincode in user_input.split(',')]  # Convert user input to integers

# Debug: Display Pincode List
print("Pincode List:")
print(pincode_list)

# Filter the data
filtered_df = df[df['PINCODE'].isin(pincode_list)]

# Debug: Display Filtered Data
print("\nFiltered Data Sample:")
print(filtered_df.head())

# Check if filtered data is empty
if filtered_df.empty:
    print("No matching data found for the provided pincodes.")
else:
    # Save to a new Excel file
    output_file = r"D:\data\filtered_data.xlsx"
    filtered_df.to_excel(output_file, index=False, engine='openpyxl')  # Specify the engine explicitly
    print(f"\nFiltered data saved to: {output_file}")
# Out:
# Original Data Sample:
#                                       INSTITUTE NAME             STUDENT NAME  \
# 0                            Ambedkar College, Mahad    CHARFARE YUSRA KHALIL
# 1                            Ambedkar College, Mahad  SIRKHOT AQSA ABDUL AZIZ
# 2  Anandibai Damodar Kale Degree College of Arts ...      APTE ATHARVA DINESH
# 3  Anandibai Damodar Kale Degree College of Arts ...  BHARATE APURV DHANANJAY
# 4  Anandibai Damodar Kale Degree College of Arts ...       CHAVAN APARNA ANIL
#
#    GENDER                                            ADDRESS   PINCODE  \
# 0  Female  At Post Mahad Park Avenue Apartment   C Wing 2...  402301.0
# 1  Female         Al Haris  Complex  Pansari Mohallah  Mahad  402301.0
# 2    Male    A G02 Green Park CHSL Uttan Road Bhayandar West  401101.0
# 3    Male  Plot No.67/C34, Suvidha C.H.S.L. RSC14,Gorai-1...  400092.0
# 4  Female  ROOM NO. 10 PATEL CHAWL,  HANUMAN TEKDI, KAJUPADA  400066.0
#
#        MOBILE                       EMAIL      COURSE
# 0  9623367734     yusrakhalil30@gmail.com  T.Y.B.M.S.
# 1  9860714934   neelamsirkhot02@gmail.com  T.Y.B.M.S.
# 2  7045299136    atharvaapte356@gmail.com  T.Y.B.M.S.
# 3  9004428741          apbharte@gmail.com  T.Y.B.M.S.
# 4  9702260779  anilchavan461980@gmail.com  T.Y.B.M.S.
# Pincode List:
# [421204, 421301, 421202, 421203, 421201, 421306, 421002, 421103]
#
# Filtered Data Sample:
#                                         INSTITUTE NAME  \
# 328  Birla College of Arts, Science and Commerce, K...
# 329  Birla College of Arts, Science and Commerce, K...
# 332  Birla College of Arts, Science and Commerce, K...
# 333  Birla College of Arts, Science and Commerce, K...
# 336  Birla College of Arts, Science and Commerce, K...
#
#                  STUDENT NAME  GENDER  \
# 328    AHIRE MITALI BABASAHEB  Female
# 329  ALKUNTE VAISHNAVI SANJAY  Female
# 332    ANDURE HARISH DATTABAL    Male
# 333            ANN RENI SHOBY  Female
# 336   BADEKAR JAYESH RAJENDRA    Male
#
#                                                ADDRESS   PINCODE      MOBILE  \
# 328  A/301 Bldg NO 2 SHREE SWAMI RAJ BLDG SHELAR PA...  421301.0  8433698828
# 329  C-503 Osho Priya Osho Dhara CHS Ltd Near Shani...  421306.0  8591424273
# 332  02, Bldg 07, Phase II, Neelkhant Park Wayle Na...  421301.0  8879076998
# 333                  B-401, EVEREST TOWERS KARNIK ROAD  421301.0  8108742641
# 336               DATTARYA COLONY  MILIND NAGAR KALYAN  421301.0  8828758014
#
#                              EMAIL                   COURSE
# 328        mitaliahire12@gmail.com  T.Y. B.M.S.(Autonomous)
# 329   Vaishnavialkunte99@gmail.com  T.Y. B.M.S.(Autonomous)
# 332       harish.andure8@gmail.com  T.Y. B.M.S.(Autonomous)
# 333           renitasv03@gmail.com  T.Y. B.M.S.(Autonomous)
# 336  tejashreebadwkar167@gmail.com  T.Y. B.M.S.(Autonomous)
#
# Filtered data saved to: D:\data\filtered_data.xlsx
